# %%
data = [("Utsav", "Singh", "23", "22-07-2000", "M", 200000),
        ("Sourav", "Goyal", "24", "26-09-1999", "M", 400000),
        ("Vaishnavi","Choudhary", "25", "18-09-1998", "F", 5000),
        ("Gauri","Sharma","26", "02-06-1997", "F", 8000),
        ("Akash","Dua", "27", "20-11-1996", "M", 6000)]
columns = ["FirstName","LastName","Age","DOB","Gender","Salary"]
df = spark.createDataFrame(data=data, schema=columns)    
df.show()
# Out:
# +---------+---------+---+----------+------+------+
# |FirstName| LastName|Age|       DOB|Gender|Salary|
# +---------+---------+---+----------+------+------+
# |    Utsav|    Singh| 23|22-07-2000|     M|200000|
# |   Sourav|    Goyal| 24|26-09-1999|     M|400000|
# |Vaishnavi|Choudhary| 25|18-09-1998|     F|  5000|
# |    Gauri|   Sharma| 26|02-06-1997|     F|  8000|
# |    Akash|      Dua| 27|20-11-1996|     M|  6000|
# +---------+---------+---+----------+------+------+

# %%
df1 = spark.read.format("csv").option("header", "true").load("dbfs:/FileStore/shared_uploads/utsavsingh62@gmail.com/Order-1.csv")
df1.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Region</th><th>Country</th><th>ItemType</th><th>SalesChannel</th><th>OrderPriority</th><th>OrderID</th><th>UnitsSold</th><th>UnitPrice</th><th>UnitCost</th><th>TotalRevenue</th><th>TotalCost</th><th>TotalProfit</th></tr></thead><tbody><tr><td>Middle East and North Africa</td><td>Libya</td><td>Cosmetics</td><td>Offline</td><td>M</td><td>686800706</td><td>8446</td><td>437.2</td><td>263.33</td><td>3692591.2</td><td>2224085.18</td><td>1468506.02</td></tr><tr><td>North America</td><td>Canada</td><td>Vegetables</td><td>Online</td><td>M</td><td>185941302</td><td>3018</td><td>154.06</td><td>90.93</td><td>464953.08</td><td>274426.74</td><td>190526.34</td></tr><tr><td>Middle East and North Africa</td><td>Libya</td><td>Baby Food</td><td>Offline</td><td>C</td><td>246222341</td><td>1517</td><td>255.28</td><td>159.42</td><td>387259.76</td><td>241840.14</td><td>145419.62</td></tr><tr><td>Asia</td><td>Japan</td><td>Cereal</td><td>Offline</td><td>C</td><td>161442649</td><td>3322</td><td>205.7</td><td>117.11</td><td>683335.4</td><td>389039.42</td><td>294295.98</td></tr><tr><td>Sub-Saharan Africa</td><td>Chad</td><td>Fruits</td><td>Offline</td><td>H</td><td>645713555</td><td>9845</td><td>9.33</td><td>6.92</td><td>91853.85</td><td>68127.4</td><td>23726.45</td></tr><tr><td>Europe</td><td>Armenia</td><td>Cereal</td><td>Online</td><td>H</td><td>683458888</td><td>9528</td><td>205.7</td><td>117.11</td><td>1959909.6</td><td>1115824.08</td><td>844085.52</td></tr><tr><td>Sub-Saharan Africa</td><td>Eritrea</td><td>Cereal</td><td>Online</td><td>H</td><td>679414975</td><td>2844</td><td>205.7</td><td>117.11</td><td>585010.8</td><td>333060.84</td><td>251949.96</td></tr><tr><td>Europe</td><td>Montenegro</td><td>Clothes</td><td>Offline</td><td>M</td><td>208630645</td><td>7299</td><td>109.28</td><td>35.84</td><td>797634.72</td><td>261596.16</td><td>536038.56</td></tr><tr><td>Central America and the Caribbean</td><td>Jamaica</td><td>Vegetables</td><td>Online</td><td>H</td><td>266467225</td><td>2428</td><td>154.06</td><td>90.93</td><td>374057.68</td><td>220778.04</td><td>153279.64</td></tr><tr><td>Australia and Oceania</td><td>Fiji</td><td>Vegetables</td><td>Offline</td><td>H</td><td>118598544</td><td>4800</td><td>154.06</td><td>90.93</td><td>739488</td><td>436464</td><td>303024</td></tr><tr><td>Sub-Saharan Africa</td><td>Togo</td><td>Clothes</td><td>Online</td><td>M</td><td>451010930</td><td>3012</td><td>109.28</td><td>35.84</td><td>329151.36</td><td>107950.08</td><td>221201.28</td></tr><tr><td>Europe</td><td>Montenegro</td><td>Snacks</td><td>Offline</td><td>M</td><td>220003211</td><td>2694</td><td>152.58</td><td>97.44</td><td>411050.52</td><td>262503.36</td><td>148547.16</td></tr><tr><td>Europe</td><td>Greece</td><td>Household</td><td>Online</td><td>C</td><td>702186715</td><td>1508</td><td>668.27</td><td>502.54</td><td>1007751.16</td><td>757830.32</td><td>249920.84</td></tr><tr><td>Sub-Saharan Africa</td><td>Sudan</td><td>Cosmetics</td><td>Online</td><td>C</td><td>544485270</td><td>4146</td><td>437.2</td><td>263.33</td><td>1812631.2</td><td>1091766.18</td><td>720865.02</td></tr><tr><td>Asia</td><td>Maldives</td><td>Fruits</td><td>Offline</td><td>L</td><td>714135205</td><td>7332</td><td>9.33</td><td>6.92</td><td>68407.56</td><td>50737.44</td><td>17670.12</td></tr><tr><td>Europe</td><td>Montenegro</td><td>Clothes</td><td>Offline</td><td>H</td><td>448685348</td><td>4820</td><td>109.28</td><td>35.84</td><td>526729.6</td><td>172748.8</td><td>353980.8</td></tr><tr><td>Europe</td><td>Estonia</td><td>Office Supplies</td><td>Online</td><td>H</td><td>405997025</td><td>2397</td><td>651.21</td><td>524.96</td><td>1560950.37</td><td>1258329.12</td><td>302621.25</td></tr><tr><td>North America</td><td>Greenland</td><td>Beverages</td><td>Online</td><td>M</td><td>414244067</td><td>2880</td><td>47.45</td><td>31.79</td><td>136656</td><td>91555.2</td><td>45100.8</td ...

# %%
df.createOrReplaceTempView("Person_data")
df2 = spark.sql("Select * FROM person_data")
df2.printSchema()
df2.show()
# Out:
# root
#  |-- FirstName: string (nullable = true)
#  |-- LastName: string (nullable = true)
#  |-- Age: string (nullable = true)
#  |-- DOB: string (nullable = true)
#  |-- Gender: string (nullable = true)
#  |-- Salary: long (nullable = true)
#
# +---------+---------+---+----------+------+------+
# |FirstName| LastName|Age|       DOB|Gender|Salary|
# +---------+---------+---+----------+------+------+
# |    Utsav|    Singh| 23|22-07-2000|     M|200000|
# |   Sourav|    Goyal| 24|26-09-1999|     M|400000|
# |Vaishnavi|Choudhary| 25|18-09-1998|     F|  5000|
# |    Gauri|   Sharma| 26|02-06-1997|     F|  8000|
# |    Akash|      Dua| 27|20-11-1996|     M|  6000|
# +---------+---------+---+----------+------+------+

# %%
# %sql
SELECT firstname,salary,age,count(*) FROM person_data GROUP BY firstname,salary,age
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>firstname</th><th>salary</th><th>age</th><th>count(1)</th></tr></thead><tbody><tr><td>Utsav</td><td>200000</td><td>23</td><td>1</td></tr><tr><td>Sourav</td><td>400000</td><td>24</td><td>1</td></tr><tr><td>Vaishnavi</td><td>5000</td><td>25</td><td>1</td></tr><tr><td>Gauri</td><td>8000</td><td>26</td><td>1</td></tr><tr><td>Akash</td><td>6000</td><td>27</td><td>1</td></tr></tbody></table></div>
